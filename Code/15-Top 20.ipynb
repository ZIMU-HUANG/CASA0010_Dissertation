# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the shapefile
shapefile_path = "Data/Revised/Geography/MSOA/London_2021.shp"
gdf = gpd.read_file(shapefile_path)

# Load the CSV file
csv_path = "Data/Final/Dataset.csv"
df = pd.read_csv(csv_path)

# %%
# Select top 20 regions by IMD_Total value
top_regions = positive_df.nlargest(20, 'Count')

# Plotting the bar chart for top regions
plt.figure(figsize=(12, 8))
plt.barh(top_regions['msoa21nm'], top_regions['Count'], color='#D0C4B8', edgecolor='black')
plt.xlabel('Count')
plt.ylabel('MSOA Name')
plt.title('Top 20 Regions with Highest IMD_Total Values')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###
